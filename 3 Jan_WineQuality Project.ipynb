# %%
#https://www.kaggle.com/robjan/wine-quality-prediction-with-visualisation/notebook
# get data set from here

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
rw = pd.read_csv('C://Users//Mayuri//Downloads//winequality-red.csv')
rw.shape
# Out:
# (1599, 12)

# %%
rw.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
rw.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
rw.hist(bins=10, figsize= (15,18))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9016/268312956.py in <module>
#       1 rw.hist(bins=10, figsize= (15,18))
# ----> 2 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
corr= rw.corr()
fig = plt.figsize=(20,17)
p= sns.heatmap(corr, cmap='Purples')
p.set_title('Correlation between Variables')
# Out:
# Text(0.5, 1.0, 'Correlation between Variables')

# %% [markdown]
# As we can see our target Quality has highly positive correlation between density, citric acid, alcohol, free sulpher oxide and also total sulpher oxide.

# %%
corr.sort_values(by=["quality"],ascending = False)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# quality                    0.124052         -0.390558     0.226373
# alcohol                   -0.061668         -0.202288     0.109903
# sulphates                  0.183006         -0.260987     0.312770
# citric acid                0.671703         -0.552496     1.000000
# fixed acidity              1.000000         -0.256131     0.671703
# residual sugar             0.114777          0.001918     0.143577
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# pH                        -0.682978          0.234937    -0.541904
# chlorides                  0.093705          0.061298     0.203823
# density                    0.668047          0.022026     0.364947
# total sulfur dioxide      -0.113181          0.076470     0.035533
# volatile acidity          -0.256131          1.000000    -0.552496
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.countplot(rw['quality'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9016/3541461352.py in <module>
#       1 sns.countplot(rw['quality'])
# ----> 2 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
rw['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)
